# %% [markdown]
# # Lesson 3: Chatbot Example

# %% [markdown]
# In this lesson, you will familiarize yourself with the chatbot example you will work on during this course. The example includes the tool definitions and execution, as well as the chatbot code. Make sure to interact with the chatbot at the end of this notebook.

# %% [markdown]
# ## Import Libraries

# %%
import arxiv
import json
import os
from typing import List
from dotenv import load_dotenv
import anthropic

# %% [markdown]
# ## Tool Functions

# %%
PAPER_DIR = "papers" #Using this dir to save the information to the filesystem

# %% [markdown]
# The first tool searches for relevant arXiv papers based on a topic and stores the papers' info in a JSON file (title, authors, summary, paper url and the publication date). The JSON files are organized by topics in the `papers` directory. The tool does not download the papers.

# %%
def search_papers(topic: str, max_results: int = 5) -> List[str]:
    """
    Search for papers on arXiv based on a topic and store their information.
    
    Args:
        topic: The topic to search for
        max_results: Maximum number of results to retrieve (default: 5)
        
    Returns:
        List of paper IDs found in the search
    """
    
    # Use arxiv to find the papers 
    client = arxiv.Client()

    # Search for the most relevant articles matching the queried topic
    search = arxiv.Search(
        query = topic,
        max_results = max_results,
        sort_by = arxiv.SortCriterion.Relevance
    )

    papers = client.results(search)
    
    # Create directory for this topic
    path = os.path.join(PAPER_DIR, topic.lower().replace(" ", "_"))
    os.makedirs(path, exist_ok=True)
    
    file_path = os.path.join(path, "papers_info.json")

    # Try to load existing papers info
    try:
        with open(file_path, "r") as json_file:
            papers_info = json.load(json_file)
    except (FileNotFoundError, json.JSONDecodeError):
        papers_info = {}

    # Process each paper and add to papers_info  
    paper_ids = []
    for paper in papers:
        paper_ids.append(paper.get_short_id())
        paper_info = {
            'title': paper.title,
            'authors': [author.name for author in paper.authors],
            'summary': paper.summary,
            'pdf_url': paper.pdf_url,
            'published': str(paper.published.date())
        }
        papers_info[paper.get_short_id()] = paper_info
    
    # Save updated papers_info to json file
    with open(file_path, "w") as json_file:
        json.dump(papers_info, json_file, indent=2)
    
    print(f"Results are saved in: {file_path}")
    
    return paper_ids

# %%
search_papers("computers")
# Out:
# Results are saved in: papers/computers/papers_info.json
# ['1312.3300v1', '2207.05241v1', '2603.19778v1', '2601.11095v1', '2012.10468v1']

# %% [markdown]
# The second tool looks for information about a specific paper across all topic directories inside the `papers` directory.

# %%
def extract_info(paper_id: str) -> str:
    """
    Search for information about a specific paper across all topic directories.
    
    Args:
        paper_id: The ID of the paper to look for
        
    Returns:
        JSON string with paper information if found, error message if not found
    """
 
    for item in os.listdir(PAPER_DIR):
        item_path = os.path.join(PAPER_DIR, item)
        if os.path.isdir(item_path):
            file_path = os.path.join(item_path, "papers_info.json")
            if os.path.isfile(file_path):
                try:
                    with open(file_path, "r") as json_file:
                        papers_info = json.load(json_file)
                        if paper_id in papers_info:
                            return json.dumps(papers_info[paper_id], indent=2)
                except (FileNotFoundError, json.JSONDecodeError) as e:
                    print(f"Error reading {file_path}: {str(e)}")
                    continue
    
    return f"There's no saved information related to paper {paper_id}."

# %%
extract_info('1312.3300v1')
# Out:
# '{\n  "title": "Numerical Reproducibility and Parallel Computations: Issues for Interval Algorithms",\n  "authors": [\n    "Nathalie Revol",\n    "Philippe Th\\u00e9veny"\n  ],\n  "summary": "What is called \\"numerical reproducibility\\" is the problem of getting the same result when the scientific computation is run several times, either on the same machine or on different machines, with different types and numbers of processing units, execution environments, computational loads etc. This problem is especially stringent for HPC numerical simulations. In what follows, the focus is on parallel implementations of interval arithmetic using floating-point arithmetic. For interval computations, numerical reproducibility is of course an issue for testing and debugging purposes. However, as long as the computed result encloses the exact and unknown result, the inclusion property, which is the main property of interval arithmetic, is satisfied and getting bit for bit identical results may not be crucial. Still, implementation issues may invalidate the inclusion property. Several ways to preserve the inclusion property are presented, on the example of the product of matrices with interval coefficients.",\n  "pdf_url": "https://arxiv.org/pdf/1312.3300v1",\n  "published": "2013-12-11"\n}'

# %% [markdown]
# ## Tool Schema

# %% [markdown]
# Here are the schema of each tool which you will provide to the LLM.

# %%
tools = [
    {
        "name": "search_papers",
        "description": "Search for papers on arXiv based on a topic and store their information.",
        "input_schema": {
            "type": "object",
            "properties": {
                "topic": {
                    "type": "string",
                    "description": "The topic to search for"
                }, 
                "max_results": {
                    "type": "integer",
                    "description": "Maximum number of results to retrieve",
                    "default": 5
                }
            },
            "required": ["topic"]
        }
    },
    {
        "name": "extract_info",
        "description": "Search for information about a specific paper across all topic directories.",
        "input_schema": {
            "type": "object",
            "properties": {
                "paper_id": {
                    "type": "string",
                    "description": "The ID of the paper to look for"
                }
            },
            "required": ["paper_id"]
        }
    }
]

# %% [markdown]
# ## Tool Mapping

# %% [markdown]
# This code handles tool mapping and execution.

# %%
mapping_tool_function = {
    "search_papers": search_papers,
    "extract_info": extract_info
}

def execute_tool(tool_name, tool_args):
    
    result = mapping_tool_function[tool_name](**tool_args)

    if result is None:
        result = "The operation completed but didn't return any results."
        
    elif isinstance(result, list):
        result = ', '.join(result)
        
    elif isinstance(result, dict):
        # Convert dictionaries to formatted JSON strings
        result = json.dumps(result, indent=2)
    
    else:
        # For any other type, convert using str()
        result = str(result)
    return result

# %% [markdown]
# ## Chatbot Code

# %% [markdown]
# The chatbot handles the user's queries one by one, but it does not persist memory across the queries.

# %%
load_dotenv() 
client = anthropic.Anthropic()

# %% [markdown]
# ### Query Processing

# %% [markdown]
# > **⚠️ Deprecation Notice**
# > The model `claude-3-7-sonnet-20250219` was deprecated in February 2026 and is no longer supported. All code in this notebook has been updated to use `claude-sonnet-4-6` to ensure everything runs as expected.

# %%
def process_query(query):
    
    messages = [{'role': 'user', 'content': query}]
    
    response = client.messages.create(max_tokens=2024,
                                      #model = 'claude-3-7-sonnet-20250219', #deprecated model
                                       model='claude-sonnet-4-6',
                                       tools=tools,
                                       messages=messages)
    
    process_query = True
    while process_query:
        assistant_content = []
        tool_results = []
        has_tool_use = False

        for content in response.content:
            if content.type == 'text':
                print(content.text)
                assistant_content.append(content)

            elif content.type == 'tool_use':
                has_tool_use = True
                assistant_content.append(content)

                tool_id = content.id
                tool_args = content.input
                tool_name = content.name
                print(f"Calling tool {tool_name} with args {tool_args}")

                result = execute_tool(tool_name, tool_args)
                tool_results.append({
                    "type": "tool_result",
                    "tool_use_id": tool_id,
                    "content": result
                })

        # One assistant message per turn, with ALL content blocks
        messages.append({'role': 'assistant', 'content': assistant_content})

        if not has_tool_use:
            process_query = False
        else:
            # One user message with ALL tool_results for that turn
            messages.append({"role": "user", "content": tool_results})
            response = client.messages.create(max_tokens=2024,
                                              #model = 'claude-3-7-sonnet-20250219', #deprecated model
                                               model='claude-sonnet-4-6',
                                               tools=tools,
                                               messages=messages)

# %% [markdown]
# ### Chat Loop

# %%
def chat_loop():
    print("Type your queries or 'quit' to exit.")
    while True:
        try:
            query = input("\nQuery: ").strip()
            if query.lower() == 'quit':
                break
    
            process_query(query)
            print("\n")
        except Exception as e:
            print(f"\nError: {str(e)}")

# %% [markdown]
# Feel free to interact with the chatbot. Here's an example query:
#
# - Search for 2 papers on "LLM interpretability"
#
# To access the `papers` folder: 1) click on the `File` option on the top menu of the notebook and 2) click on `Open` and then 3) click on `L3`.

# %% [markdown]
# > Note: Some queries take longer than others, especially ones that call search_papers, since that hits the live arXiv API over the network. Queries that only need extract_info (a local file lookup) or no tool at all will feel much faster. If the chat looks like it's hanging after you hit enter, give it a bit, it's usually still working, not stuck.

# %%
chat_loop()
# Out:
# Type your queries or 'quit' to exit.
# Query:  HI
# Hi there! 👋 Welcome! I'm here to help you search for and explore academic papers on arXiv. You can ask me to:
#
# - 🔍 **Search for papers** on any topic (e.g., "machine learning", "quantum computing", "climate change")
# - 📄 **Extract information** about a specific paper using its arXiv ID
#
# What topic are you interested in exploring today?
# Query:  Search for papers on NCCL
# Sure! Let me search for papers on NCCL right away.
# Calling tool search_papers with args {'topic': 'NCCL'}
# Results are saved in: papers/nccl/papers_info.json
# I found 5 papers on NCCL. Let me now extract the information for all of them simultaneously!
# Calling tool extract_info with args {'paper_id': '2603.13606v3'}
# Calling tool extract_info with args {'paper_id': '2511.15076v2'}
# Calling tool extract_info with args {'paper_id': '2608.01449v1'}
# Calling tool extract_info with args {'paper_id': '2507.04786v3'}
# Calling tool extract_info with args {'paper_id': '1707.09414v1'}
# Here's a summary of the **5 papers found on NCCL**:
#
# ---
#
# ### 1. 📄 [NCCL EP: Towards a Unified Expert Parallel Communication API for NCCL](https://arxiv.org/pdf/2603.13606v3)
# - **Authors:** Amos Goldman, Nimrod Boker, et al.
# - **Published:** 2026-03-13
# - **Summary:** Introduces **NCCL EP**, a Mixture-of-Experts (MoE) communication library built on NCCL's Device API. It provides `ncclEpDispatch` and `ncclEpCombine` primitives supporting **Low-Latency (LL)** mode for inference decoding and **High-Throughput (HT)** mode for training, evaluated on H100 clusters with vLLM integration.
#
# ---
#
# ### 2. 📄 [GPU-Initiated Networking for NCCL](https://arxiv.org/pdf/2511.15076v2)
# - **Authors:** Khaled Hamidouche, John Bachan, et al.
# - **Published:** 2025-11-19
# - **Summary:** Presents **GPU-Initiated Networking (GIN)** introduced in NCCL 2.28, enabling device-side communication control. GIN supports three operation modes (LSA, Multimem, GIN for RDMA) and is demonstrated via integration with **DeepEP** for MoE communication, achieving low-latency GPU-to-GPU operations without CPU coordination overhead.
#
# ---
#
# ### 3. 📄 [NIXT: A NCCL Inspector Exporter Tool for Observability of Collective Communication in Large Model Training](https://arxiv.org/pdf/2608.01449v1)
# - **Authors:** Ziyang Jia, Sirshak Das, et al.
# - **Published:** 2026-08-02
# - **Summary:** Introduces **NIXT**, a tool that enhances observability of collective communication by exporting and analyzing data from NCCL Inspector. A case study on **Nemotron-4 LLM pretraining** with up to **2,048 H100 GPUs** demonstrates its ability to identify performance variations, stragglers, and root causes.
#
# ---
#
# ### 4. 📄 [Demystifying NCCL: An In-depth Analysis of GPU Communication Protocols and Algorithms](https://arxiv.org/pdf/2507.04786v3)
# - **Authors:** Zhiyi Hu, Siyuan Shen, et al.
# - **Published:** 2025-07-07
# - **Summary:** Provides a **comprehensive analysis of NCCL's internals**, covering protocol variants (Simple, LL, LL128), intra/inter-node data movement, and ring/tree-based algorithms. The insights power **ATLAHS**, a network simulation toolchain for reproducing NCCL communication patterns in large-scale AI training.
#
# ---
#
# ### 5. 📄 [Optimized Broadcast for Deep Learning Workloads on Dense-GPU InfiniBand Clusters: MPI or NCCL?](https://arxiv.org/pdf/1707.09414v1)
# - **Authors:** Ammar Ahmad Awan, Ching-Hsiang Chu, et al.
# - **Published:** 2017-07-28
# - **Summary:** Compares **MPI vs. NCCL** for broadcast operations on dense multi-GPU clusters. Proposes a pipelined chain (ring) design in **MVAPICH2-GDR**, achieving up to **16.6× improvement** over NCCL-based solutions in inter-node broadcast latency and up to **7% improvement** in VGG training on 128 GPUs.
#
# ---
#
# These papers collectively cover a wide range of NCCL topics — from expert parallelism APIs and GPU-initiated networking, to observability tools, internal architecture analysis, and performance comparisons with MPI.
# Query:  Extract infor from 2507.04786v3
# Sure! Let me extract the information for paper **2507.04786v3** right away.
# Calling tool extract_info with args {'paper_id': '2507.04786v3'}
# Here is the extracted information for paper **2507.04786v3**:
#
# ---
#
# ### 📄 Demystifying NCCL: An In-depth Analysis of GPU Communication Protocols and Algorithms
#
# - **📅 Published:** July 7, 2025
# - **🔗 PDF URL:** [https://arxiv.org/pdf/2507.04786v3](https://arxiv.org/pdf/2507.04786v3)
#
# ---
#
# ### 👥 Authors
# 1. Zhiyi Hu
# 2. Siyuan Shen
# 3. Tommaso Bonato
# 4. Sylvain Jeaugey
# 5. Cedell Alexander
# 6. Eric Spada
# 7. James Dinan
# 8. Jeff Hammond
# 9. Torsten Hoefler
#
# ---
#
# ### 📝 Summary
# This paper presents a **comprehensive analysis of NVIDIA's Collective Communication Library (NCCL)**, a critical software layer for high-performance collective operations on large-scale GPU clusters. Despite being open source, NCCL's internal design has remained largely opaque. The paper addresses this by examining:
#
# - **Communication protocol variants:** Simple, LL (Low Latency), and LL128
# - **Data movement mechanisms:** Intra-node and inter-node memory movement
# - **Collective algorithms:** Ring- and tree-based communication algorithms
#
# The insights gained form the foundation for **ATLAHS**, an *application-trace-driven network simulation toolchain* capable of accurately reproducing NCCL communication patterns in large-scale AI training workloads. The work aims to provide guidance for **system researchers and performance engineers** looking to optimize or simulate collective communication at scale.

# %% [markdown]
# <p style="background-color:#f7fff8; padding:15px; border-width:3px; border-color:#e0f0e0; border-style:solid; border-radius:6px"> 🚨
# &nbsp; <b>Different Run Results:</b> The output generated by AI chat models can vary with each execution due to their dynamic, probabilistic nature. Don't be surprised if your results differ from those shown in the video.</p>

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
# <p> 💻 &nbsp; <b> To Access the <code>requirements.txt</code> file or the <code>papers</code> folder: </b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em> and finally 3) click on <em>"L3"</em>.
# </div>

# %% [markdown]
# In the next lessons, you will take out the tool definitions to wrap them in an MCP server. Then you will create an MCP client inside the chatbot to make the chatbot MCP compatible.

# %% [markdown]
# ## Resources
#
# [Guide on how to implement tool use](https://docs.anthropic.com/en/docs/build-with-claude/tool-use/overview#how-to-implement-tool-use)

# %% [markdown]
# <div style="background-color:#fff6ff; padding:13px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px">
#
#
# <p> ⬇ &nbsp; <b>Download Notebooks:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Download as"</em> and select <em>"Notebook (.ipynb)"</em>.</p>
#
# </div>
